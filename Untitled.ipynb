# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal
days = 126
trading_volume = np.random.normal(1000,100,days)
for i in range(0,126):
        int avg
plt.xlabel("trading average")

plt.plot(trading_volume)

# %%
e
